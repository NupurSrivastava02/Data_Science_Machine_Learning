# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %%
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_features=4, noise= 0.4, random_state=0)

# %%
X
# Out:
# array([[ 0.42625873,  0.67690804, -2.06998503,  1.49448454],
#        [-1.33425847, -1.34671751, -0.46071979,  0.66638308],
#        [-0.91282223,  1.11701629,  0.94447949,  2.38314477],
#        [ 0.74718833, -1.18894496,  0.94326072, -0.70470028],
#        [-0.1359497 ,  1.13689136, -1.06001582,  2.3039167 ],
#        [-0.13288058, -0.29779088, -0.39727181, -0.63743703],
#        [-0.63584608,  0.67643329,  0.03183056, -0.67433266],
#        [ 0.29823817,  1.3263859 , -1.09940079,  0.37642553],
#        [-0.76991607,  0.53924919,  0.40746184,  0.67229476],
#        [-0.38487981,  0.09435159, -0.73067775, -1.12682581],
#        [-0.39944903,  0.37005589,  0.58295368,  0.09772497],
#        [-2.25556423, -1.02250684,  0.38728048, -1.69810582],
#        [ 1.86755896,  0.90604466,  1.48051479,  1.92294203],
#        [-0.20690368,  0.88017891, -1.57062341,  0.64331447],
#        [-1.00021535, -1.5447711 ,  0.84436298, -1.22543552],
# ...

# %%
y
# Out:
# array([  48.30859938, -210.41468887,  117.43391419,  -35.61272969,
#         101.40514653,  -62.00718272,    3.74684147,  106.54768246,
#          23.37610821,  -66.15344433,   27.89763081, -264.02924318,
#         295.38265263,   22.50459883, -199.76685158,  230.61405607,
#         -66.73099541, -148.72705797,   50.0606763 ,  127.97789286,
#         -13.18227538, -150.90074353,  -25.62002233, -112.64807087,
#         -29.91139675,  113.94636599,  -15.08451298,  -64.30770311,
#         -95.78047322,  116.36732852,   55.28427895, -251.71819141,
#         312.32903255,  100.39681992,   58.15633287,   55.96064176,
#         -24.43889329, -129.8272655 ,   13.43108276,   99.52986583,
#         -20.23003948,  161.75514844,  -85.09138567,  102.82617396,
#         110.21321514,  -69.6068193 ,   79.06545911,  -52.6854206 ,
#         -62.48251792,  -82.54806425,  152.30669583,  -86.52695574,
#          94.6824599 ,    9.16712065, -100.62476914,  -30.39111996,
# ...

# %%
X.shape
# Out:
# (100, 4)

# %%
y.shape
# Out:
# (100,)

# %%
# Check for Linearity

# %%
plt.scatter(X[:,0],y)
plt.show()

# %%
plt.scatter(X[:,1],y)
plt.show()

# %%
plt.scatter(X[:,2],y)
plt.show()

# %%
plt.scatter(X[:,3],y)
plt.show()

# %%
import statsmodels.api as sm

# %%
X1 = sm.add_constant(X)

# %%
X1
# Out:
# array([[ 1.        ,  0.42625873,  0.67690804, -2.06998503,  1.49448454],
#        [ 1.        , -1.33425847, -1.34671751, -0.46071979,  0.66638308],
#        [ 1.        , -0.91282223,  1.11701629,  0.94447949,  2.38314477],
#        [ 1.        ,  0.74718833, -1.18894496,  0.94326072, -0.70470028],
#        [ 1.        , -0.1359497 ,  1.13689136, -1.06001582,  2.3039167 ],
#        [ 1.        , -0.13288058, -0.29779088, -0.39727181, -0.63743703],
#        [ 1.        , -0.63584608,  0.67643329,  0.03183056, -0.67433266],
#        [ 1.        ,  0.29823817,  1.3263859 , -1.09940079,  0.37642553],
#        [ 1.        , -0.76991607,  0.53924919,  0.40746184,  0.67229476],
#        [ 1.        , -0.38487981,  0.09435159, -0.73067775, -1.12682581],
#        [ 1.        , -0.39944903,  0.37005589,  0.58295368,  0.09772497],
#        [ 1.        , -2.25556423, -1.02250684,  0.38728048, -1.69810582],
#        [ 1.        ,  1.86755896,  0.90604466,  1.48051479,  1.92294203],
# ...

# %%
model = sm.OLS(y,X1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.033e+06
# Date:                Thu, 11 Jan 2024   Prob (F-statistic):          2.49e-233
# Time:                        15:03:35   Log-Likelihood:                -52.560
# No. Observations:                 100   AIC:                             115.1
# Df Residuals:                      95   BIC:                             128.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0073      0.043      0.169      0.866      -0.079       0.093
# ...

# %%
# Check for autocorrelation: From the above Durbin-Watson = 2.054 shows little or no auto-correlation

# %%
sns.distplot(X[:,0])
plt.show()
# Out:
# C:\Users\NUPUR SRIVASTAVA\AppData\Local\Temp\ipykernel_4228\704766593.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X[:,0])

# %%
sns.distplot(X[:,1])
plt.show()
# Out:
# C:\Users\NUPUR SRIVASTAVA\AppData\Local\Temp\ipykernel_4228\4041135053.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X[:,1])

# %%
sns.distplot(X[:,2])
plt.show()
# Out:
# C:\Users\NUPUR SRIVASTAVA\AppData\Local\Temp\ipykernel_4228\1939741104.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X[:,2])

# %%
sns.distplot(X[:,0])
plt.show()
# Out:
# C:\Users\NUPUR SRIVASTAVA\AppData\Local\Temp\ipykernel_4228\704766593.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X[:,0])

# %%
# Check for normality: Above plotting for normality

# %%
X
# Out:
# array([[ 0.42625873,  0.67690804, -2.06998503,  1.49448454],
#        [-1.33425847, -1.34671751, -0.46071979,  0.66638308],
#        [-0.91282223,  1.11701629,  0.94447949,  2.38314477],
#        [ 0.74718833, -1.18894496,  0.94326072, -0.70470028],
#        [-0.1359497 ,  1.13689136, -1.06001582,  2.3039167 ],
#        [-0.13288058, -0.29779088, -0.39727181, -0.63743703],
#        [-0.63584608,  0.67643329,  0.03183056, -0.67433266],
#        [ 0.29823817,  1.3263859 , -1.09940079,  0.37642553],
#        [-0.76991607,  0.53924919,  0.40746184,  0.67229476],
#        [-0.38487981,  0.09435159, -0.73067775, -1.12682581],
#        [-0.39944903,  0.37005589,  0.58295368,  0.09772497],
#        [-2.25556423, -1.02250684,  0.38728048, -1.69810582],
#        [ 1.86755896,  0.90604466,  1.48051479,  1.92294203],
#        [-0.20690368,  0.88017891, -1.57062341,  0.64331447],
#        [-1.00021535, -1.5447711 ,  0.84436298, -1.22543552],
# ...

# %%
df1 = pd.DataFrame(X)

# %%
df1.values
# Out:
# array([[ 0.42625873,  0.67690804, -2.06998503,  1.49448454],
#        [-1.33425847, -1.34671751, -0.46071979,  0.66638308],
#        [-0.91282223,  1.11701629,  0.94447949,  2.38314477],
#        [ 0.74718833, -1.18894496,  0.94326072, -0.70470028],
#        [-0.1359497 ,  1.13689136, -1.06001582,  2.3039167 ],
#        [-0.13288058, -0.29779088, -0.39727181, -0.63743703],
#        [-0.63584608,  0.67643329,  0.03183056, -0.67433266],
#        [ 0.29823817,  1.3263859 , -1.09940079,  0.37642553],
#        [-0.76991607,  0.53924919,  0.40746184,  0.67229476],
#        [-0.38487981,  0.09435159, -0.73067775, -1.12682581],
#        [-0.39944903,  0.37005589,  0.58295368,  0.09772497],
#        [-2.25556423, -1.02250684,  0.38728048, -1.69810582],
#        [ 1.86755896,  0.90604466,  1.48051479,  1.92294203],
#        [-0.20690368,  0.88017891, -1.57062341,  0.64331447],
#        [-1.00021535, -1.5447711 ,  0.84436298, -1.22543552],
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(X, i)for i in range(4)]

# %%
vif
# Out:
# [1.077394127139436, 1.008288213819014, 1.0662751125524454, 1.0372357005345723]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
# array([[-0.06824161,  1.71334272, -0.4615846 , -1.31590741],
#        [ 0.93184837,  0.33996498,  0.00377089,  0.69845715],
#        [ 0.74718833, -1.18894496,  0.94326072, -0.70470028],
#        [-0.81314628, -1.7262826 , -0.35955316, -0.67246045],
#        [-0.4555325 ,  0.01747916, -0.68954978, -0.80340966],
#        [-0.63432209, -0.36274117,  0.3024719 ,  0.06651722],
#        [-0.63584608,  0.67643329,  0.03183056, -0.67433266],
#        [-0.41361898, -0.74745481,  1.94362119, -1.17312341],
#        [ 0.04575852, -0.18718385, -1.45436567,  2.26975462],
#        [-1.10438334,  0.05216508, -1.60205766,  0.62523145],
#        [-0.02818223,  0.42833187, -1.18063218, -0.51080514],
#        [-0.02432612, -0.73803091, -1.61695604,  0.64013153],
#        [-0.68783761, -1.2140774 , -0.4533858 ,  1.0685094 ],
#        [ 0.15494743,  0.37816252,  1.46935877,  1.53277921],
#        [-0.59631404, -0.0525673 , -0.50681635, -1.18885926],
# ...

# %%
X_train.shape
# Out:
# (80, 4)

# %%
X_test
# Out:
# array([[-1.03424284,  0.68159452, -0.65102559,  0.85683061],
#        [-0.31155253,  0.05616534, -0.57884966, -0.87079715],
#        [-0.91282223,  1.11701629,  0.94447949,  2.38314477],
#        [ 0.3130677 , -0.85409574, -0.20515826,  1.49407907],
#        [ 0.61407937,  0.92220667, -0.15501009,  0.94725197],
#        [-1.42406091, -0.49331988, -0.23792173, -0.59731607],
#        [-0.89546656,  0.3869025 , -0.21274028, -1.61389785],
#        [ 0.8644362 , -0.74216502,  0.6536186 , -2.55298982],
#        [-0.94444626, -0.41004969, -0.4664191 ,  0.78632796],
#        [ 0.46566244, -1.53624369,  0.90082649, -1.16514984],
#        [ 0.52389102,  0.08842209,  0.1887786 , -1.93627981],
#        [ 0.72909056,  0.12898291,  0.0519454 , -0.90729836],
#        [ 0.3563664 ,  0.70657317,  0.97663904,  0.20827498],
#        [-0.20690368,  0.88017891, -1.57062341,  0.64331447],
#        [ 0.29823817,  1.3263859 , -1.09940079,  0.37642553],
# ...

# %%
X_test.shape
# Out:
# (20, 4)

# %%
y_train
# Out:
# array([ 102.82617396,  108.42683057,  -35.61272969, -232.14750896,
#         -69.6068193 ,  -62.48251792,    3.74684147,  -51.50314408,
#         -17.12483568, -112.44794403,  -14.99813659, -107.86013358,
#        -146.76802295,  125.66567465,  -86.52695574,  -64.30770311,
#          50.0606763 ,    1.3778631 ,  307.86582484,  149.84630301,
#        -210.41468887,   94.89375099,  -85.09138567,  161.75514844,
#         101.40514653,  230.61405607, -148.72705797,  -20.23003948,
#          13.43108276,  -62.00718272,  -31.47423927,   -6.58415666,
#          48.30859938,   58.15633287,  -95.78047322,  152.30669583,
#        -264.02924318,   55.96064176, -112.64807087,   94.6824599 ,
#          27.89763081, -251.71819141, -220.04921497,  104.93694072,
#         -79.27260788, -154.4273576 ,  312.32903255,   -8.03735732,
#        -199.76685158,  -20.44875519,  127.97789286,  116.36732852,
#         -82.54806425,  -26.05121642,  121.57367924,   91.63608474,
# ...

# %%
y_train.shape
# Out:
# (80,)

# %%
y_test
# Out:
# array([ -15.08451298,  -53.70464503,  117.43391419,  -30.39111996,
#         136.83579188, -160.43714119,  -66.73099541,  -37.10272428,
#        -100.62476914,  -96.7294646 ,    9.16712065,   44.05998867,
#         122.76712745,   22.50459883,  106.54768246,   55.28427895,
#         -25.62002233,  -29.91139675,  100.39681992,   23.37610821])

# %%
y_test.shape
# Out:
# (20,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.9999904480418356

# %%
model.score(X_test,y_test)
# Out:
# 0.9999648793109162

# %%
y_Pred = model.predict(X_test)

# %%
y_Pred
# Out:
# array([ -14.68149633,  -53.69363268,  117.61252817,  -30.26949742,
#         136.7133289 , -159.93619513,  -66.79289104,  -36.64263542,
#         -99.6815911 ,  -96.52165667,   10.06063338,   43.88422169,
#         123.91490762,   22.87919277,  106.8968463 ,   55.50468393,
#         -26.03059688,  -29.44018362,  100.16093606,   23.1017908 ])

# %%
y_test
# Out:
# array([ -15.08451298,  -53.70464503,  117.43391419,  -30.39111996,
#         136.83579188, -160.43714119,  -66.73099541,  -37.10272428,
#        -100.62476914,  -96.7294646 ,    9.16712065,   44.05998867,
#         122.76712745,   22.50459883,  106.54768246,   55.28427895,
#         -25.62002233,  -29.91139675,  100.39681992,   23.37610821])

# %%
plt.scatter(y_Pred, y_test)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
